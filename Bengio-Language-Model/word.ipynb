# %%
import torch
from torch import nn
import tiktoken

# %%
# Get data from the dataset

with open('../data/russian-novels/WAP.txt', 'r', encoding='utf-8-sig') as file:
    text = file.read()

enc = tiktoken.get_encoding("cl100k_base")
enc.encode(text)

words = sorted(list(set(text)))
# print(words)
# print(words)
# ctoi = {c: i+1 for i, c in enumerate(words)}
# ctoi['_'] = 0
# itoc = {i: c for c, i in ctoi.items()}

encode = enc.encode
decode = enc.decode

encode(text[:100])

# print(words)
# Out:
# [46558,
#  3651,
#  22557,
#  5693,
#  1432,
#  1383,
#  37848,
#  59602,
#  267,
#  2303,
#  17146,
#  337,
#  88341,
#  1432,
#  262,
#  36962,
#  271,
#  262,
#  48198,
#  25002,
#  25,
#  220,
#  5245,
#  20,
#  271,
#  262,
#  96424,
#  358,
#  271,
#  262,
#  6969,
#  2599,
#  2505]

# %%
# Build dataset
block_size = 8

X, Y = [], []
X_test, Y_test = [], []

test = text[int(len(text) * 0.8):]
text = text[:int(len(text) * 0.8)]

for i in range(0, len(text) - block_size):
    X.append([ctoi[c] for c in text[i:i+block_size]])
    Y.append(ctoi[text[i+block_size]])

for i in range(0, len(test) - block_size):
    X_test.append([ctoi[c] for c in test[i:i+block_size]])
    Y_test.append(ctoi[test[i+block_size]])

X = torch.tensor(X)
Y = torch.tensor(Y)

X_test = torch.tensor(X_test)
Y_test = torch.tensor(Y_test)

X.shape, Y.shape
# Out:
# (torch.Size([2566610, 8]), torch.Size([2566610]))

# %%
def get_batch(batch_size=32):
    idx = torch.randint(0, X.size(0), (batch_size,))
    return X[idx], Y[idx]

def get_test_batch(batch_size=32):
    idx = torch.randint(0, X_test.size(0), (batch_size,))
    return X_test[idx], Y_test[idx]

batch = get_batch(32)

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.C = torch.randn(len(chars)+1, 2)
        self.W1 = torch.randn(block_size * 2, 200) * 0.2
        self.b1 = torch.randn(200) * 0.01
        self.W2 = torch.randn(200, len(chars)+1) * 0.01
        self.b2 = torch.randn(len(chars)+1) * 0
        self.parameters = [self.C, self.W1, self.b1, self.W2, self.b2] 
       
        
    def forward(self, x, y):
        
        emb = self.C[x].view(-1, 2*block_size)
        h = torch.relu(emb @ self.W1 + self.b1)
        logits = h @ self.W2 + self.b2
        preds = torch.softmax(logits, dim=1)
        loss = torch.nn.functional.cross_entropy(logits, y)
        
        return preds, loss

model = Model()

for p in model.parameters:
    p.requires_grad = True

# %%
x_train, y_train = batch

optimizer = torch.optim.SGD(model.parameters, lr=0.001, momentum=0.9)

for i in range(99999):
    
    optimizer.zero_grad()
    x, y = get_batch(32)
    
    outputs, loss = model(x, y)
    
    loss.backward()
    
    optimizer.step()
    
    # if i % 1000 == 0:
print(f'Loss: {loss.item()}')
# Out:
# Loss: 2.501145362854004

# %%
# Sample the model

result = encode("War and ")
print("War and ", end='')
while result[-1] != 0:
    x = result[-8:]
    x = x.view(1, -1)
    y = torch.tensor([result[-1]])
    preds, loss = model.forward(x, y)
    next_char = torch.multinomial(preds[0], 1)
    result = torch.cat([result, next_char])
    print(decode(next_char) , end='')
# Out:
# War and them
# Pé they
# ghey the osarper, dransyne breelh Pe H co leAteon aluritupfes. beyl onheestwasd fepe als ane,
# itifhsgingst he Pas gas dal wingeng Alpat
# w,e then
# him loith! angand yep tawd oufite. paid him. and tott limsáou andards,
# “Wyichey agosllit’.”,” Tied ap neys cei loupesl
#
# “Oep in letterow, le pastse paskhe?” Sv
#
#  DHeouan, femaller of the wownou hisfeon and dhes Poellvnoun ind that therrent putúeoud.” deins did feribe of tunaley tat fouchter
# mteated. gut lBaw
# Iritte wob
# and f2ale—
# H clkith ind lelicsid his to coIr eebaise bet of anith wasród hiol Sar de, sacderard the
# dourdy;d?” Din lool ob fean Icotelinco thar hud proy, dhoulantean, rhe clentesing denemesared
# cobe bthe (roit bentav
# S her,”
# beoothan. Bad, hee Mrinces Kothing dit,z Wurárr The tritcostr beadone Pny that themiding
# The
# nise thec Coyper of avunter,” Inad bl mund” Fedd an, an ouge betáow mitktin?” he sace
# the
# duddt Nounon’en
# wreelhed to mef
# vnl;—Iengter to woin he. beilder bat, jemh a mork
# bOlHs, Snasd, the thet oine pitlitt,.
# “Whtar Sóante To the
# dirtontan evely A and Doun her cretaealns Fis locoroin?
#
# Afioer ind acpyidy Ildes vet mlpáale eule. ane almy wefe the surnte buighog
#
# “urss.aw thetonn
# the, brusenc. towones he had alsut’íy
# “Wan she bacceingolf. and sonds, gher cratke Anming Sucose
# “*kouted to Noom heatt.y an her lre an hi treng
# dean thube fesidgl,” Tos the
# foodsóss. cehners.. princelesq.é Ivme Bedsevfe’ hal! blespsun, to ses vufhte?. hithen
# of tian
# bet sou Oun ntate, to to opuad. wop foigenesanstone pusseds spalkr.kovnt ath prige bernele worsing with
#
# fasalins
# rou anr” partiour Buming totáangide. “usser, inteous the
# fomegisy of they vmetitt thmte, a mift meuding. end
# gat at the undare the pame oute tere parfeny Thetá A ande And dtro mhith
# “nt yepoidy
# Deceng had hes byentel,”m.
# “e kes poddel;, to peked, ald In thee the elmurbelas’er Disyn the urf centars to iour off Roin the jerd und rpabkyd
# nes “evuluth sonteother hem sadd and frook. bat dhoulsean
# so, bom. ansestem.ang the warderces!” luen that hous the he.
# nis Rorh.es that her, Aour tutoule gun ofay hi’ dethor doter
# fount the dir.
# woun bou your funds dtory Wlache and
# Y“u wus— the seag at Meteous thas mom béy mefy bre
# ras in that alfy
# Yet op oyteae
# “eent betíe meiths wise alid will whe Ghe
# nemreltadd punslellan’ed sertkilbdagh the
# Esouthersed he itm the
# lus.ad woml
# the Drince an in the
# wronter Srfýúan it of tháe rratthsl.ish hame us his aóthetse’y. seoca. durtaren, Hevonad muravntong Rcok the lasin dtily
# ther bou no anince to bein at hear af, and has treetichs ith
# indwove, werssringey alke flecelead in ind eler his cuttlu futh bumulvy thou,” Il res
# vxloutt tres
# netserfar, Rein Ieset,en
# e jner eut mimeng shem theal and to tisd the Rrapoidd.
#
# “thesulalss kud, had ttin. ther
# bet her hetupiou, lre ontem,
# from she nethermer mingow the lratinen Iosruvard Ièwucinity withon,
# aoinge had yefkont ag thecelars, she fadcawttoundt an tuar leetol
# filine
# Dxt afsornt he talegont to
# lum blomeery themu, of hith afpyad, it the Fnuce wolnte that himss “arnmy Ioml Nhem of worionty her caeke tupouky and prebpl,” they the hemes mle. tued the “usy. nuther prut the qyemyee! Pringe Vawd eozransa of once the fy wisg ceether
# sakv
# Tomk
# tamnáon, to
# meh
# I beintele.d
# wivisitk,ar taikd, and felaupe oaveone, and vor’ats ho Yefokf Hifr yl the fittare abicy is to ceas took and defe oá siesed nian in fourd
#
# “Neb
# murd epoutt he mertasnig show came apro me mrous the cou kropham his
# olfettef exinte brerlour pydimnsaol wer
# peperhad.. a’ icpasit. we neured an the semverd then me deing be
# dig pomes nte
# putterint tyut he the eostt morencan Itinen wealeontey ypoumy,” har einten in otiont ite whice wadíekEnotce Dighon.”. sou wtacpent. suig toteour of cout hom
#
# Sée Ixl him, rrey. ond, andy Hithing topkok umdy anathad that shecing
# the cursenens in mes lout bicá
# ausagsov cett etoore Dr ex atlaided.
#
# SWoupusken?” byesothethed dirleatisg Nus deserisss bPedTrod dportr to Peesebetten ateon, it meo? pery treno lan ketáotive pein hotú
# Dtam as a defrelede,g,
# Sre Eirtle hid sive. Heer and befe cooned whom alre ilutcecasso ceaviseon, at moumedting her epiching thee the woymthingcon, sutmlin! wucs. cuspesicscyagt aidt dilod byee, pumeonsenuse sooke, an il ut afd Ml bepe ofhun ‘raml hes arledids pat eyullertelss, D,fultitinf
# yed movde. and A’el, ar, nem.
# sery rhitcl AetyrhmRpeddá
#
#  Nhe Sown,—uping “ut arau, apdald and sow bour to apean no
# beeclting thin led nome Das fant talithour, tat purelean!s, In eoicod hour a lesised The feu hir toss the foclá that odfhopitls themur? ar she
# hemm, shat eeed beethers hot’ed
# Mops, anneate the paskathens Naotte sind asanceds mitapisg of to mef, Hourd bus araul, voekoigs qecsods,
# ret thee ifpans lume. but louk roma, bettl ofme wod’chew
# the corinaons al dad, fois yositter wesiaon furpaw. phe they jusá wes Pisteoesy
# Tuvk
#
# “Yheriont he weme the hotidone asy awdin yran, cur ofeele the almed betú and terúeneseenst himhsay of tho
# lodsa Hased., Wattóvall Ifok morow—aredd thes the mingeon and bumé Pevhchi rubkengens foj chelpsom fagking the srither his
# brouthed eudy thet wasd
# Ptael. bexpine heangsh the oukue as the pot Paigh,
#
# “Ape begy a coirtetiw and Preod dithoy, musint of the othe
# wap moth elauss suncarl,” of qy a chóener rert mee co nundecs.ol,” he wistee ce cer, Kemb Dingl, but tow themy coul
# A mlicebyy Ar cacprhuther saym “e kady ov eoemovarsl AIet tother the crecfron hes pokkL an
# maichtey she dhe. thein,
# an rhe selrs alk ar the touttr.r sororo
# ynrritteon
# to somtucl dovechis hem hot lacqusn he heelse Vedaring. and ascensl, pith thit wutte thoaaingey terevidfesloine said to how and the poomin luticente fDingess, genitels,
# Piml HO Peviti wont, san er as
# auk,
# “Cy. feqin,”.. And her fein sar hes
# borm thim them. hip kall wat Befod Asopph beninge
# “Napeoe! uledsem As moukd furime meefeete maging mromad,, Bas dadf use dast sining ap the roratis fowde afd Mat’ov
#  I
#
#  *ak ponti! puthotseb. Aier dilm hees habeblod, meoing Mónan an nistola an lose! hele tatysyr Rvst relcedat’en fish and pumingrr “nither
# woltown is peasing and mite out Cors has pontid”
# mtut colg. Teml..
#
# “edoinë
# “ut ot the lowe v;felez,
# Not her dhen to
# feid of the ranter Peta?d
# “ors,
# Rringed ani
# itíoudn of mou the
# lralowme, ipsacitioned Vone
# to foush ousrle.
# bude ine of it houn hed pare to
#
# geaP bett’itt
# of toníate to sutsit he agherel is rore she tupkesacants that fe
# pav.” “ud pops mom hon’idg dhoused yon nith drit at “urusain at mLart beyatt by.easy Annarl Nued the ankle—pe sowvis one the extyrhs, Mrar he weid the allenf! whe ligseyns. Mret bsouddtyavl Hhetod oy peitta had hid lore hot he poo kel pigher, andy weitcin’ yased doucds the fou yne e ende hor ro bthene” pith uf, wut saskoby morner.z, and Roirk Naim he comd” ner hesebol whe Frow. hir putseet,” leith the goomve wosdar, ant, the bent. lutttiad tlrolrsmabidbe to head a sald!
#
#  The prixnded betrers, tale the tre
# mtumt:,
# naled the lifyeped—nathar ofnutskad to help suw roun the susedd
# “Aeáe, phe liktlesn nherent theusvobr M8icher,
#
#
# AgeIn bcaev” bTinceridg.s
# “Bamd. Nne suid,”
# deitecllocsemongel the Frels’ín, A
# undsybLn
# rretely, ltucl, an becorec, and piisrreourter’’
#  “op, wuktayde Ditt see aym, inse dis mvetint to louldneow and thin his sarrer. and alpye poynt a kact leit the Mosteins
# thef o8 the printhast dl.urud
# ketht ousone seectent the bifedq) “ule yithis.
# S
# mlefts Weedteasd Cerlrh wretore ters nemrly” and that asme llow ther. the
#
# “re bagkeitg., und iner sid fien ande opti itheru niart ofrres’ au kast the pastr yill Weith heirtthun whom indes.,
#
#
# NelteEas,”
#
# Ifinch
# madt lupocatticuose lpealfing onk dume bat dem,” ancome
# therces huath pear a rank by thew wietsedeon, that be the dimstow rhanin
# otiscer him—
# tham, wot to mlery autrit:v Phdmi! he usawce fIekol siur I bostée,”
# vhe fame
# deok
# dhin firy, htat as the garkeens srre, the wplona—talf at Sot wpotintat’ed fun shot has the Ftos hetgebE peingsoun lepethains Yein it his dom. ghes the mor ol oncensid vot— ontucly ayen.ich of daige, she hon lrow and hat and nund the volmien.
# “Hne pourt the carepets srig the licheer Hiss of thet, wuf butesgayl “ally
# juyirgety
#
# PWeace in desy
# ben butke aut lomdl fnet. gamy
# chemeasce wof to the Pousol hyl ande
# and the dos leAso,” lrovis Moun tat lia. tuid ane
# “m Cring yesyets at the
# grow,
# “ tasíe, tetefe
# Bosts SVGarenter,”” ramthesuz laid fhation ros—ptic A tur as allegwer to point he buported Inm offyrk mes? the sosdiss mo.bgude, ner didted ratáomed hay the haddsile, he pIlce
# and sordly
#
# “ene b damd by the
#
# the mopkits an
# dlamlees and priniling “lontól the hempevf he krareas. wistesf, Ve klur of etimpe ho pamlonidtetis hatseon btis anmmoss—ruteasm’l. itilkly. wird un shecheces her bos, simend but oine
# Pisn a rer
# mettoriee.e. The
# comaneon whey
# wiad a ecyroofs chat clOseing to menelrsp filpen, ard ehdeisend cUow! arpr.epelfsUf b“ Pife todde terark her vseming ond tre b hear the sau abs gritfet ceos hiol Nhey he therens et hem inssingl
# to vugtóomr. angy al thering the terf Sus’er, pus Oog govk- fus sake vl
# mlen-d Asmenn asd sopphing the mucleide tumtes am fe feetselu’ e wandscsuteowotining him his has balesidtutis.
# grevphte cticin the fudt the frant the dhutceritces weelan jratteh
# is wie, the thifsingle thas hir shiml thet on
# the code hag vett thew intont humarh, the bagyorsów dold teratgey vtooth ourd. of ghowissen
# ani” all qmfone bre rimnrrev, cantevisicyeingthicshel
# Incw Hir ene Pout of them coth wous ate
# “eftelféitce and Budin ay hus
#  Anor masdke, her nostasar and difl cNocor akd has ptoucand.
# “Hat ovpariTherad antansed—onfs)z “Weasing letrard, dutíetens I fort and u wenserg,”
#
# tit cowt teve,
#
# nhi enince Andaluby.. Geremnt pame mude bit’en it the cint hith pheantl the dud pefiteonsid her
# mor’isse’ Thi- mrethec’obfey.” paily of thes,chse. Whit wtather ut mir ve mes apst of Kefh and the siourf Auid perel. wuat Mistty feta od eroceleon’ buen, femler, atd in the pooking “e an wheme jeassoin.
# fan ineres burtitsanin” wpok Ivoulu.!” ofluntivilfasls. tavarh in Mover
# pukein! Pattov wrrol andy. Hifh afards my the otmes Ruun—rhem wev wich of atoo
# retrt Reering hit to Pea to oll pisisIsi coon
# y his loth the sezser, to fid tovke mire puilghe Stitint pre dowe, buinine mer movpF Yy Pelpe! avened wiflsou caronese”
#
# “è veke. laind
# foat dou
# o her they hem wifeZled Hin cerelets qafa berakf afy. Mutáy tat it the Nourd
#
#  “nithing it ley let herithinsese hed gearnecyonterp the buseour Nevertatt og the calking
# und dheth, ghish buid.  the feastenings.—tunr
#
# Pead or! apd.. Pnutitht the plat whine, lpincenchat hiesren, comleen mas the teal
# of.r fabfove atis dik ofe thing wice!
# ‘r
# nealsed wamcet ruc
# gor” this folh”er it doislatuovfd bat time apr, bepted
# Ixitn book any pimle le.ebang:ókcabpe?er’temeans
# “akalb muridung saing, atdad, gorí.
#
# Aé kei”d, andydaw fudt laitt, Al!ethter coun had rarechouss af warsebeme cind mesuth.’, the punt him.
# bucen, pat in atingant fosing u sealr, bre
# to thaagh arting ardenced she oom. and at Sath, Hedo the comeshe soidd dith it the wart of
# sie antit,”” hat by wied
# and” ther
#
# “Ourice
# weethey pas yuil
# Wait hel has deipe anexrs hit ceal out ol vyol of Dene un the cast ofe- her Dothlrun he hud sean her nom.. tan Iin un themid dtape belun ofall the hudd. louls, wethife’t, Mow anded waid the luu eou in hier Pott a foad montund.
#  Bhe lomvizey aldrawing Mas, on the founteoving “l the Crifedts fat it ofdy Wv
# the, and Yet suseme wairh Nixe astes; woste end bommr. of the put, ity the father,
# “ hear No ham, te tet
# éynats in mrecheorny
# peakion out!ound To the arey. Ping. tals dhe sasking aukrce wait outale
# at e fmope a wevei foudr on a one it.
#
# “at the cuondz wastucs
# atheoy wilerts, neeritat, and the ruin the’ tomme, Ititce wod? intirg, the euplroleon, piisl,, rosditt hit qtuttis,
#
# “Youted ruphinge Seared
#
# “ that salk nes wagkans,
#
# Hlefenterynn and the mopt ile, heas. the Lrititgl fol
#
#    CHAeTense, nano intsesy Fid tobl
# bGat?’ At the cigtór bucl,
#
# “Whe malv of hes bos dnan bre pame Houlen-l Sort the
# dragce puth vacyourd fin weal (esh he wed that the (ovd wingeok to the these weig
# foun iny saeld
#
# “xninge “aid, and the posthses ofichalangeopDonteovrm-
#
#  Der vit dors Nhe oldoy har thes bsemerean himhsatt His.nsard
# beeore
# Af mou soont the saind bucesud Iltuno as trhou daskeng, hat sowe tat too, mory on the
#
# Wout afin an whe hes.ors!
#
# “ef meces At wuth him dut. crou te fos hengser cacíyrAtiled
# to cer allród.m
# Pmwír:iggsets Rhot hatáesile tatían wan borh,
# “hat roède. the cenechatsen, tolartes Fieginf. Ko ape ale grinr yuenen byul.
# greèerg
#  Khe eorttuith por eime thitt has sure the treelf, pount coukd of the creisst mether lout mergeriiling
# “Tou ar the prench, taiciser, ynice as hor
# fery aut medintef soaling. Nhise fat ove an wint his aler Nomp. supo myfus oun leress ainsyesance  “emenmati—ing qéeruwd of A rXatk, ctitteare Parkevirgey bnoy
# Peerser hus the ler
# ner vilt.. laesles he tor Ipáms
# theag. Anker,”” the some
# Mekperp.” tho wemfy
# Sethartse. ind
# “Yo ofletow Iníencurgen ttis the cured fecaileovetis. they Eitters c)iting. An ancuv
# her
# wtat Pipsen, haus Toun is
# seistel ofdr the wedcesening at am,”
# tadebingion af Ip to
# con meleod to geris au! molithoug an wade hem
# somisnon, wether hid his sore,”sky on
# thetre. bietetsinebhars shay, asdedd,
# and
# trecú bee.”” beat thet as saboute it fetumondoy’ whixr the wervd Il the dusginge
# the dalle., a cwe rhite andn a to thippor dxich
# the nad sout ofoum elat rhe
# berel.ing ofqreend to hes enyreks poaged exer i woge “eth
# feratilv
# lH and hother hampe hel hem aclesy wacingont oode he shes, sefbising and peph iprrye oul, her cre
# wul. lin cHarhtes, buge the bethes That difts it
# rirtsu in bounind it the ind can hon, peir drenothes thes’ther her fasts Sekhens
# u ser of Nomoonitise ind duid
# tel ab undants.ailhtess. Dis at exftre Comimn oflnetecelc, ity befdt to thealing hith hed bye oful. of thim
# (icy
# Cotheind
# and pe
# cag in.
# lefase pee
# wutteth ghemz!abce.s, pour foun he poun a sas tho saxl to ttacpelmiceegilen, and wursed Tytt Ke
# nacalore al afe an utains..y
# Bot the loule, hug beopengm Indad fhice fathensun weme asiter, sookr dimuse woul! bepit out thi dowsed and
#
# thitfone bon to thas itse Seltoide of the khat her the eeit fort rhe kenele
# rasm! and, boresey. an the fetteors; Halidted fYemB ofsangsy alpez the foman to bnitter,”
# ned and raclsonded
# itingsouden
# hir nowdzh!k. iothou’set.esicloneny
# O
# their
# tteath end pavme and sot’tov inince llene!
# asd atyeleid to leunk? Inom the to mevunotyes; faid the disseefd focm the sor’em,
# outher himasad
# atich buthty un the gutáer., Buse of Weivin leccan thei,”... “uasd ono
#
# untsaw Jhisle? an avlroniele faleon bv
# gatuin miererg bAfe tod duin neid had
# gomer hoi,”
# “reap, mascy”sk.. rielrtateode Meartion at Oilend yá Reard that had thl cee ceetored they Muv, shim, befuld won bosidted and,s thayther and cuelpe bunttssit pongsis fadd the pustean axt arint tat ro rienid lighovy Hoetand’
# fpill bme ol Bar the paceide
# “
# hotishs
# un wesrared fyan hee fort the wisfen Fithey wipeanse An
# bome. to but latten he? thinged andiadh l’incelu, weer. and at the tretsssome, and gai”
# nur fre
# ark al the Nusing craute. Istale, Mhit e mvloutid
# tot houeting tore ely. And, thit hate Rlen kesoigh u the wrouth fro
# woulyone” and the Fust ontis dour ourcun the trene” thom
# e dnow heke youly dith”e whimk wer hess out and owan mo,nab
# An and indr Hidkhe sur, autto abperitg. “uirttone hather andyyod and on the lultolter’ of thet it the meas b heesTening?
# fugran yesss thelinceds
# Mit ftom himeri alv wotk, and abpy onmsean en the ruk miteld,.
# Som wepes
# wut the
# yaid. an syat—y.” Arot No lepe to alsard tas ispyowsA, er the gugtev
#
# One orpe atarps
# therar esain to timl meas, is fe,
# ene weth,
# ntoy and shit ar pefpovkcorth Suin the duid tuledan himllf “BMwking., and Hacationcs.
# Anpar, Phoy séath
# desh.ed
# mentwe,
# it the
# finneot, sot to bnersoug the cmomy
# arous is mou ket, theiring beltting
# and eme
# roindá HHetc,”” hesvshin parisy.. jisamisg the nif:ersó’fat’er daped” Itad axctotyonse
# tumalart mfiother foring
# the Fousk “emesing WWamlsoun epancy’uolsi covy” bwas he antime,
# sed? himnee mulzse Ahtars
# Sual Sevith, blzakead them. “utteud. ceoitht hen and an digheoge.
# Buscessstaimun hith a shere ateye she alrh then
# mar to soye foseolm and
# hisgod if icy ann simpene annaorathee, Vrrit, gume he sebpe Frale on fhe ne as!ouent hid
# ghe nos hef coule” ofe goml come ráont dhe Suant hud cealked anter’ef
#
# Tyeelangetici. that of
# rabke
# sek Docetem—b
#
# “ Likh his pain
# nhe vBey a anmint to
# eid mooken, her corennky
# Petol,
# pompent he wit to the
# coun, and
# the dicether brotyeich
# bp
# Askrs goit hodsin em
# stapins se, suriniclofe;ír, at pheechmy Dlep his pien
# phe Arsants
# uloutect myase trink the *lingea fraw wether, hed to Pef peloid, Mrelalmd ‘v Nebwep’ Nordersing Tad nume bC comy Kow batá in ruly,
# neacor to the sut etomldengr havbe the betttatsen at, se.n then
# wtioth budd Durgelads. once dor Ree and dief
# u doukd
# of fune. tha dhear belsing he Iound High,
# and on the lun ganesy,” she
# yn inser peefeel, row itato whottheart his toos Rpou-unt lith of Marfod ho
# fes michieflicef, a luntlee áx som. tot be ane eud at fest of
# seepritto Pitcle.
# cure of the Itow awd
#
# Tle champ befeteby Ifowed
# A hisrlat.elenin htane the pentteen
# mormy sow theau heered O
# fy cavalrer potks towar ofunt the bome ar a onded, guse
# wed
# hincest Muran he
# thoursatkon andecastly
# mesea)h a fanteouidges, the
# w ravenme and gatte’as, lent the
# por nhar mustorpe bale neal it an,”card Ian the ble will
# “inta ous owfersetu’ Prale to wem. theh bastan
# tatisiounts NAl. tek comeng, womrn.—
# cúlme
# ar gatáetitc in i por in lod keceoun ave
# of he the corde wtocee ontwyar’ ofter jud—rhil.. beSneer. sompok Dortl-,
#
#  Yeetu! of a on tie ron
# it thimpef
# pook Is Fis fotton mxad, nitharse. couce, dhe Anar ho toins to cagre. mlamin the womeEentl dla pot.: aminthous har’ed dadd by
# wad and shef theust bupisuns
#
# “nery Dis siddrond to bepuran hith mor mengevit anded he pout the fen it ey. pvrnun, and cwat the croclm!
# thet her bot tirid, him pagseri.g.s.ottin
# hte
# acouler cosingastt.as Beir dhingexl me
# kirh the a!me?ter:
#
# Peop welnt des,eud wid banteds and hes
# could Hxlontitgis beesre?g lol sosár pmosed lackeer; Mxited ho pirtev) Pidr
# the noo
# so
#  dougud hime fas aw than had hern addryrt the prifh that thesenele to Mis no noust and
# sou dier., the
# pm,nepsh, dain dat laean ghit fuiging cNhe books of vIuiling fhai hed the badace
# and and lert boplanc SWoy theig rat sovsed.
# grayeene and garseing
# No coos ar the boríar, thotgiartt flloucy prer
# that med, taindont
# OSpelesh the lud to is otimf hes.
# now, haw pibhabitt fat tome mlase,
# That adf,” wole, gaty the sook
# “Wtheusht of the fasmatcudfichatied onsw alphes
# noloyintld
# “Thser her bicho Dan eseaght Pietht.
#
# Per hitht in ateol, the subsarition worant him,
#
# “okeI axin syifptunss,, Swichev himseale.
# sawí.,
# nid nerh
# a dorgaes semoit had be criethens dow ratkitt terye wedce?nse, grencedà, it whe her creye.h.
# nun aw Hosusaridns., hes cant hep bather bice cibv ond tot dand yeelpolmetk Sennaesy To ontnegs al tairen, burmsuk,” and mor guy the mmíuming un the lomme, du, fume gade atout Mar oun luming hefrert he nuened we taaling
# the posringtiml Milsedg.i” cramg.. It the fmos to the Eeleaing
# reaig. ogy kyy nas, Nem ners. thouken ofcheid
# bading
# in the dusing thatsth.surgidend
#
# “We Fale to fed. of the Anre wake and Ios the Hrattefy and shat hudd
# anm go meeveoce seesyd wigh he, pinctoidd, duceskod thoy hus in turcel
# Noogy
#
# “H beflnsou her, arpresaml,
# Mitpittou wifsed offyabend’ “y the Tomigt sim,
# Suety sot polr, i mabk lussow..
# saingtyatsitsar war dusinfy, cowkeoe keth,” cudd “ecus!,”
# “eredó
# shat himtert themlepy—
# Otl A ble wastotáe bround dith is ani noulingt hin sints Dississ Nuveseoyeeese, himur cod devleube, hear, hial
# hiss, tevieted kusalnt tuasd
# fottieest buthing, wre.ing altrer
# Aount hit llastingh britce to lakkamy “onesnencóy
# Weteon, Mosh.
# aritk
# “Yhiche. Wrotioure wos teke eeft he pre and to fomosineve furd” ofheesy. frictiman heit thu pasdy of the Rom moukthou, ciphow ind hred lee wemèrunder, Iemx coes seatt, it fieldon him teat and’on is wothee, Dninged
# antyl Datkur the ceeldert! Toste
# mríyoul Ywoncher
# nere en his oun srepíl
# owy the
#
# Pistuf diching uns’eord tuk bean yofis on the beprod tis ypheched
# weal
# andths., hel d’etise andrawm,
#
# “Y
# dou andoi and weart litint un sea an e lulan it olery tot hie ded a himading fantthed
# bering, and koser’ SDingtr Mlnerd
# gurass!” thease lhe ptol the.e of dis finn
# ar yes’raled
# l thaok—fow the Eurelitt athors the poup. and youl
# lekingl,
# “Wht the cpel, períytht suis Rif nome and
# dook as toomerteyl
# ghem,. Ppinges crerly man pusme an
# the hasteffy cone ov thest dyelean buthteavr and ‘umtowe,n buathings, and my fef bot uvence out ob pacsileons
# dhy Aoits, und uoty
# “eent A
# fpylnol, Ptar osducromry loull
# Pes hit dolou ket sifent ax ias tauring “Y
# penen musema met hime ledfon bIncersengyseigidgst Tuhted the salering
# wat the fele muve bD aglrunted “uit toomureenge fudd Bossicary by
# hatsetaw afd
# abyeir? somenter, cupiseoyeól, a pau rermfyan Htem
# the gan qousin hibl he itucy toses,
# at istteoine, he haid. ne dus an farsns out ut lot chit to fen
# Notelery
#
# “X Saesin ind
# mastor, Mrelkrh at wifasped and bering as chex rasn.
#
# SWlhe protted erdorings up tirf
# Ses, wolesing in
# serer? asdid nier the an thicle the pol! the the inm,
# brit the tatelran buresood af than thee
# muusgek arcecrlo., hamd onteods baif bm qeurg, bporan we gis; sol! beved a pasetov somed was doang allmpith rhe wingc and
#  “angeatt efsingian the. werda
# Bo,n the swrter the sFan, od oxk-
# “e isd Ixr afd pase
# thet weat ullousy sabfecelyxliant clhe han bone to geuth re buicileomntaddseceed it hey.
# the
# ceZitir a tez foupw Famv
#
# Duthen is it, indthed the pakinfl uf the mour Who duf,” RMfh a musytithing. of Sost nem, Psrer. One oflutkt the heghas es the cometion lalimw ity brew,
# vy
# pamcod detgout move creals thote unteriou him apusoun dhe caintbl supnoon’. ceoe asá
# gyerningl, mrow somo, withon it wesú thot mretabe taleping “ukpiong and gurperkd Fis ned Dis sosesiti..,
# falelulent Bor. exm. wrsen, otound
# “oing Nedd Par habpsinuly of gume mer gus yromenemskphe. kso her cant rol
# pucoul, heail. hertea, photels,
# dacant co ler on thr cuin krisgr, luithin buu and vuratt that eyin to has the femlsr puruscyousg,an
#
# Teoke wed the of malery mIerun kramke. bylanc
# worúagtling’ weth téan” meiscw
# aveon lrom
# Phinc
# nar onaute
# yoktad,””.; tooing Hime nut mine crit kron thee, deas to feing tu’irel then mlor whoamd be belmlus fy the pos ofrings “rae sule con kontlss fighav ixulee but og the lmoy it, mrur fuang, puitgtule but poun itharen prrertevlNsant hhe polid alichow wivoy Rrooke no dolty
#
# “Ohaw disint
# deathing tomor tho fereol the criched putsersed
# vint cite
# aut mettarten Imising, wourad ard ceph bHfy, wes che mit ofe”
# nou peupltefing. enchings. hid
# mifeladtr ur the
# geci:ingr in
# the puid hethey inerelsiss, dhot, hus
# byeevitt “ou kose ol the ankses.
# sow ousonok teat, ftom op nun tule mice, to the ftout pontod waicen,
#
# Boit-r ancarssom andar, the onme of the sound
# “Iht as the drryfw Asein?on an Yrur.ed ap the erd wrreakd af the cricéelsiteon moriselichon htincids Sneling. And
#
# “Dek.
#
# “Ilpve pu!an so hed berassad in Mlmy fokestt fole, on the
# wal to bsean and sank Axs, and thel
# he biluon,” chetcesede. byox, flouttevin it peow
# asd have Mec
# peth in hes wasned hot fearl: cai” her, whinge Andyrur pivt the
#  “lty fod the nomlee fejucmein the fone ind pattr Rustsin endepo
# jush u
# wueryann the mossed:y ba’clitrengs of ald
# Rtheatible
# “Coi. tomlend ytat becen “ Bo the pupin did
# wumed
# nas pyepe’gsicchemd whe rasmle po an sissing ml
# tYpalk then hus lalk a cuwt Nesy Non hen
#
# “Xpeso?, bur, the srinke Asinct the etu’ fyeos intt thath dand trenencocie! relefes Wolvacedf., papuours the welley creontyn
# freyffyichc
# shee tre fomt the suml it and bUone alleeyreleol be kour and the keated A gaghoy by Pangyhid.
#
# “Ic og inde, her toleteane And thes, and ceelantk At hot bial aben.eyd Pl Iutcs dur, theuchs.
# Nutíoutogis suve at eeculsel- of hal to the pyrar waumd
# Hither
# ander the go Ceice ner aytin
# bemuthed ane eonntith beruling Seitins bezSleiviny” and his bothen
#
# The *oupre A
# phome! pepenc. “at, Pe menefe he tak so Gusle seings tikimle bole poind
# eth af fruncers lesd
# ard her has srott and sompeky ne the cagelig oute ‘ume vuth a seefey that convarhenclu, ineyd bon
# shat Ped apfuad ser theth in holeely.
# That lointter, what he paout lycthed an bucidn oflibite oncevv
#
# neln.e, he ofingele the sor the elmlingant taseould seicing thatuch enenchadd he bl amt, a
# phetíid tordíid. cove prowe koov fot herlehe, he dur to Niai, bettes the ket oft thin high atay the dourd, “uttsing, or him thatded treephan’ onimyltec’?me bettzks
# Kir. at oYl Rate wis lorttame hus taleng alparid thess wistathed merj ondtachatton thae reoe ar the Pusiciny woichered” at in
# nhese
# sli”d
#
# “
# Bavk the pmonked to at, tulasy. fusere—an at an hath
# his eedincly Tlep theidsly fontin him. hem Wlon to
# nwascalsunt had anky, and
# festlon, attovrh-owde, he heigh winess chrusg and bov no fo whot the cexp. Ditansed in the. befemez, Ru’ gein lounst lereare lay weid to
# dentáer thes sand cowrshú rittud, fur
# detkeosey,
# se Neyy Sile! depitá bel myfathen,.
#
#  An heid he hei,
# ghe caren
# O
# Be ank than osmitt’is
# doud feamion as the pritceisg,
# neasvytelekenchich on Neaf, and sonring
# Non tutessacsoygse kun cet melvebeetisgetas, an I firtleyd har wune.”
#
# andees fassingidabing his hin afmy and rrid eélutand this lur dour to rus thoulecesying Hl
# nas dhot madd to cule onel,” Aflk, brosoned.e
# Dow rtut bom
# it fousd Ter silolr Ltom her nasle, Ktat mvoomindoy efdaca!dsom, tumettety in them dus neapol anmev to these and potidvoused, ne wiaw en
# the fast cay,
# Patiote! afv wettee enem to sefork
# bWhin? and,
# weebet, it tei rent hot himhtris tome bunen
# cotion,on and.m
# the slateny. Anq theighs to kekl,
# Bor beeng her fobe to fe arts dear puid the duussa solrruv mlo raming! and of the romks. maving
# flook.” Cetun michudf
# fOxt myar ond at the co we serd Muj cor nis
# nesserg A ralarheng
# Aar the pouk one in wou ket werú feáor of the mrolce ilníy prif,”
# they the of hos befematg
# Afdid
#
# the deptm Stlomm fun! her lanping afmatted horlesuytt no weimtodd weow therkeoust,
#
# “ out owd mititovisí.
# the foukevosach.r.e cler o ntean
# gurdone wef homl boining alnrald the
#  eok of o cen” ovfeavey
# Ghar that samem
# Whe a b or wamt ino, hak, wod, a mlacore, beid tousí.” and mrow.f
# fed he daulened and hiy asmetit thes,” frigssr he flone alle
# The armope sos sumurind ar hemsimed fot buóttot’
# Bow be bye Sut matudden, Apool to mut hather bit ear and
# Toun the soul, reth then
# bekú. Mith.
# Bo glelus cobemuridglur
# barcting ar the Tavme her fon,er,”
# fow realesgit ol her humd
# the nas offottl  Ihtirod e
# to dou ritht yusmes’toush liarssing neathed yaitingitiá antirhid brotibe ain hisebe as his frit usitt ind peet of b
#   CeePTh ner ntalfigf Annf bA the Eefyaded ly pnum
# vDey he onnrirh, dloutans Itode sert ep the lorsóunts anfrew” wethe mivethens the
# gisabe wiatctor sot theur nemll
# it wersell
#
# “To m anyir? Arinme, bertimuridte the pomv
# “  A ceise tom
# to asher mtin vy the lroteot’y and yiming me!neved cute bount as the Vegee, he seasses hathets of i ancrheated thatione ouks is rhimale porvs.su, him Dtince Anerinbe blon the atty
# Aeling btom them. wey thep mlcthe dold.ore Mau the croom
# ‘esáarsed and
# “erg,,”
# “N Mingenci). Gotáets.ribenand the EeisceyrC. b’other whal the figteou Boen in tte forchat dile.
# Bith his dead the ofdesrool, wow thet lous grene whisce Bed
# show, his cyavuntenc his berte
# thepotteo bickes beid 1rd ibpan ond
# an shat, ard and
# tugps wethar wod patteo
# rats. cres ofin tad meampon omdensr es gene Cou duity charle.” af it by wisced him, the giemant tur bedn.riff. the cuins.
# “D the tusneon ond ar to
# po areonhed. “ordich’eng... Whit wuake thot hasith
# and sowR the snemenme wez the prawcins Eor, ixpanted arnsow mmcoftiethen, hem
# cant oItaid, ar in the crerchsebcrinc ot the en tíoted vett uvur atór ol pert yeer Por the puttais ner ales. methoy tis ho igpir cart room to neup
# cexent in arauvy an sope seinger noine simateenibe same at ditht lyomd, somfen, andacldut- nomd to glear, outh oud bivl nes thes
# dar oriat.r enitcel
# ghoughims.d
#
# Ihíoutebing ludart ryoun thed she Alpott Mes wan
# orlhsed woun tiodr.
# dot purridg do Dle
# vird the sule and din ne
# peitt ind
# an ar urred
# batézy,” wetheg
# ep the nedt yound
# “ he wes pune eoud near ard mints aleravy.y al de korder wuth to fod Dxne?dent hir etmlacel Sronovich ind mer
# saw od the Btherun dhe lusin?
# “nat er the comlsonde—youst.m the entse?bmpe,””
# A sould to a lale mus nom, Pef and
# “alen an bee lob Dmeount Walvne ale
# bl
# Other tump ghor a vun bnnyr, asd.ow asder to him him moundy the o
# en theng Nale hercale los bb raching tole Towm tous-y yus pain ondeb
# inechess. wen
# dived in jettiousteds plimk
# vphe ceth heap., jtince Ve?r. “echad, putht urdoodriceon)y BuUen ardtowping fit, weyd her, ha, ald waraont and vasd plis tay dhour tham the intersomt we
# win nud hoord  “ “Ce Péich hil noun out Hith it
# phatde. bor!ótuyin cre nourr an the has iv,
# guinge nel; Gein ope pasy. lekh bexurth and itauce Hev; Anince
# “Iy:nirg he yearte hes
# bety torter:
#
# “nat fowt Oy sos, Pour in oftheró, in hava to his epeingent and an his in ather ap Pighud dot pardatelr. Had bnercl pifing and ewas of
#
# a oneseane bee nom. end cand,” a
# saroreooy mout nourn”
# Nide hat an wisl,” at yl ath, I lase Dos lor anmirss
# nhe muttt alper Voye and crilling thet shemegute fithed
# frit the beeok.. “artle?s “orgelle.v
#
# Aáthan in wets alk the Aopleeew his pithor pepoagh”
# “W *argin!”
# bicher wopl
# Sritce And festh and she pamesanate
# liicen,
# SYex ipfount und qucher thev,
# masidcsm
# futhev
# wyow bIfe of had meelM the wertl,”n and wefaou heureona. Bo houl ded vuchon’, wenn
# in, Drinte Andoisstoun, hon lisior, the sonvude, by the bernice, jetysition, surdey mut
# michousidasts and torde prang.ing,
# perentey,
# Ine At the tome wounse.s fos, thetk ard yval fick war,” at dith ise neadal, old ardther thit of the
# end tiat surkow,”
# an fyaw, afl ip Sorioe. nte coureon and wessere loulinyet potninger cangenshund
#
# “Iltuncan
# bain pod he sane ottuopde
# bein her elouph, Tuleaned
#
# “Wow gace blering to the domront checlentby hil,c
# Plhe soid asition, ter ald beert afe e bmttuig naitt it the
# itte on
# the lear,” mein the to the Apperisunt Ml corsawd, I kldnvids the fomeobte Ped gos the bitht in noul ous ob the pminy al Ml aut lef.” howsad esel, likuya yeklaw the cor,” suthke! Jigtole
# the prey woraoley hiad let drdace afj lessiel.
#
# Che coreared,
#
# “
# ait, bexred her sith Dpforvv nut deith—oa ine acmeriche masisy
# atuate to sum Pou aned wirpenan Bo
# mun gank. italy pusk boc hm
# naled fach torrrelev
# in wes.” enoles.. Ipied”
# mit,
# “ilv’etg to hoow fur, hem no munsecop Kas séome won and
# tame mtency grat beelett ov mug mint, and phe ind
# cadtse ase
# Nep d apá
#
# NHe,” besowvincod tren
# onither
# cuv
# dowlings HWan?ers. dlat ofm
# an the codbepe efit mead her hoid tattcrigh atid sont, srang Heily Doid-,”
# and sassodmd” vut ovfichov wad nonded souling he tleett ofvuity our amougy heme wreme hean at hes larttyl
# fichte’s rhey antinderod, animiny pain mury en hee, hithed flame dpomererte hapdaet at i have seerl?ak..arh
# putri’ge endnesh and re bele. salorseedd” ne tandecP
# Wemett cas.s.ed ind cergle wighey paricion,”
#
# Te dire thein lui” hi hud attyatt to covonts Xigen asd cren
# “rou
# no sein hith.y
# “etine,
# terpente fukls bomfan.d
# sadn Nikinetse lepeaweucmy avkenin ytouth and wora tót the doune tinf the cSlitht of har that bees,
# “Mal, beising of Pous
# brocde, enem:e the sudd? bet kisiotiots afone
# se pos me
# wasce—idgt?s the bean of thacle fod- hem,”. dush
# fape! an andtre thin Ilot’e whe creapentyy pount ceich,ge Avines of ran
# kther harteon, hhat.. to tho dease? hothen
# trel, that and resule asq one of his pold
# hith begarizen dham the traon vugame, and
# alet himeousy fourd coon a beíinend on the blbea sunderad his bain shat itroutt onter an thy drbker
# nattly sas
# they byeming of Yerea, bf Natter buitteing
#
# “umk?”
# Vlèokn, fitn almiding wer hinesh tho omfleak-yy his fy sribpingebu,ged Pre
# seni! har lat.e
#
# HW Cemtk2,
# shetked Teïyassota ind ceom rhe olhy) PG rhe whould out to kucusor it mee nhe coutey ethar os the I onmy
# yin ani fur!”ing et the gis! on in he,
# cousint the hem gouit.ous creith
# kp. ond
# ard prit Filn not lre poit, ntriths
# napalar eatt nemllett ux it fusthed intsebe re taan.ing
# a kunt hem robdtiveud wadiging nith of the gian ktey Fitisds home blom, Itve hadr out we deisuous Zy the Eokmy
# I batyer gorong thi moft the woud feak,d
#  Nenned’t tuth of the towsy Eale hedsyd
# fot buth as Whe kuntor.er mutt the bernow, the sostant of,ense. seaned ly Betclound’k ‘ydy aneen htal
# fetale peuid Petiss the elvRash
# him
# frecongó muktudíeed The dad
# notse wod
# to a latáovt. Chanes, grehgeping, bIfe ond gertecsow béletsevdnous poinged Wreyertly Piound nile ho
# rani” Aud the gsuckers;.n
# Walttits., he wedd” at rri” ho broke seich army ror’ew of aloun we
# atit has my
# we)
# asd Itatt saw nor to dase! e fustow and Pett oflynirs Buat of ther pobente’ank
#
# to boowou co hetsoits and hin neas oor.. af douted
# “ meew rhe puredankl that hissol
# nur ovnemfesd
# “ oerupe yith a harsincape yranced Sut she
# peaun ote breitsr wessing avletu. and
# contits Hour
# Teyask. chicping it Nurt befelp
# ond
# the to aspe nem
# nesen. Antenve pant in the lifter.
# crit wiel, of fhe Pomen misy wolfimled boiced wek thet the hour, the jipttans her powtr That repíe mout bee peetontshc
#
# “(.ers,” atenimu, ask tlXns at the otherene has nren
# A caleoud Dy Axciging
#
# “Nethem. of he
# tlene er pounds
#
# “Yan her nigh
# gpe arity Nhat chithen syaste
# A meri tod Dppame yow
# so los Disk ne his.
#
# Tly Rige alley
# the fefleing wicheretalb, that Prol, ooth tutteRtin
# tow noul pot bvnner
# Wheris nii” Ptispe. he couth rour and soul torú Pat lithots and it mua yon shitoun the erantecioul cetiou mI bapl ta’ a wumsond pauping atseon.’us, that bickrelfe luintt ne prear,” el Peince thet
# lisin; nim yyfothe andotayfpotid mos derkesuns the srer
# the sortiead vuce pettodd,
# rhe Gnieeens beir,” he
# dads of hiss
# guation pyloG a hanse. tandinll ang is
# that josly. Bhinceule “tid, abe to geil as a sank Kad
# fhok Nadd hug lothe a the
# peoded
# “U Cevllode Mou beth srat wide, the bramld Ininces, bunted sritteomm, bodethea, ar a part
# disesirt cond lpitce yolr. to cIlom nas incery theagint then he has car, the lrylHtuosisitt lU las an the fená trat the har, and hat thot, the fechmroidd gho Mlmce medt ixps a feat ale tifsh’apis tume and nur bto wercitt aalant and baed “at so and is to ixou sou mór
# wort the had seiid wed gomlue Inertilf—fteceoige
# nar elle anrole
# Tow it ogtiapn a meingous,”. wit berea fucest.emel
# Sacw hin luieint so baigd roud to to feere Dud nis num mitteredd the Hotc.e Nrelingid him teanged..” his faicet buc nian,
#
# “Y Gunteos’ pefe anderíasd aty mrich.arc.
# “Nomr the eupsol
#
# “ came Suckoény
# dIad and gSryaleon seaged Bhe mosttasudé
# pwat u gour findeling
# “eparhou dadttian worseb-nc, semle’e Bou to to thou end
# puor hish dounderey. und wan nibin deroigt teme arpimf fadd batheser, gouteas yalmather pyer. sus oure ther alve.
# “1n,
#
# HYLokrsv hin som dour pyante. wrelent aut he hevp po gucefs ofral sruritgtot ruinged, bull aov! Paun.
# A*tule the puttiming
# the said the srow ho Hire toly and hes. wer peserce and tomasy dither nar not sithor a,de thet cous the caifod withsent at duysev,
# antor dl
# Mungssaud misest, andorf! buite deníroseep.). crisce Atom,
# the ofit,.
#
# “Ome abe the lrom the
# ruoring.eph
# betuope in the faidsersusce” and
# dut at at ineb
# a wlichins all ovo wesavryd
# fuwdan fe! Iourd and wl
# Kad, atdengu ctat in the fere coue or amerodsis
# fasetope, he hed fimhopancr bAmeow tery
# theinte, her coutun at the lele, eiid it Prince andarsed wirrou had enetlpezntt.e mart sied sapitt then. Hesionte Suokly,
# antesin—e catefi,”,
# bydpwacR. Dadd Set che caad the commeer.. “ume.an. andsi’eonad seat, of a onoin pot hin Per co
# eint mettee, Iounter ded he agf up the oler.ers breefhit ror dar
# of the pean whet lou nul back thime wtatcetsl
# ondacord of the Ranter. Sl the Eur mou he feink ansaringclatt ro paseonudd and tor
# sovn that of marksut dnachte to himsingsont reid ehd cinses
# “Auther.. fryw
# the pritk thes hes
# bear the crome her patt al sasalb. bByrarev SD cask hej koan o
# chec the wascecRuleoursyr “ós nar
# wupl iny nem
# mis, and neittudd home wath Nomoshing at uto ofnayd
# “y andy mieyr, ther
# coumd of a doreue anantsr’ onlidsr
# in dhes’ing we mus”
# becesi. anke, had mor to wis or thea, her
# mentel the woumend it thith her pout thoupd Pmichteich and seell, ghoufd,” Bomamened Mils and. as
# herdi
# Petyenid, that beounsan in headd vut pukuens
# the velth beitt it Gaus and Peuking e andts
# Axths by the pametinc Dalele pome that the sear the afsung the rritky. atth a prew,
# sl
# niched and cakionter homser the
# pleld of
# fey
# Hyd
# and thel
# ghey gheteesling  “eksu Aer tumta at the wool atn ofkichad thin wastalestbing
# ouid an thi anded’cant fu vus wysing beelrul,” fell er the bace of exurn
# littly cthefow ho
# sout the poom of ag pon mivk
# ogl.e-1d butht oflir. in found
# “Ywith fetá and beiteh.
#
# “W
# Pilh and fase u cane arpe ofpcer,a. and atd hes targ of dótucmed-nc-tuiden end clope bule,
# ned drat the to cl vekontem head he arserings andtyon saslnoe bearclp VIir dulrek he repame coucesorioy thatelar onm hame My
# lamaring Wum an yea ras the full Sage eon ther hus i wirger tat vene
# nmifk,
#
# “Wot ifdsrov
# dteasesn., Grouly
# rFesing he soos the fomseare che the prid
# ut. peatchith lusera at the fapwselsm,” “yparce Arat, in Fop cait oupe, his ditser
# Irdcoon
# and
#  HrmurEtye’ens and de
# ithar her
# thel the how hither bwimint nathed, on tait hied moman vukeoe in
# princ to weichey fitht epluriti!f Rir, a urdemd
# the shote the fepeise imtyears, n’an they entacedice?.,
# Hetevlr. Nakmary,””e
#
#  Yeterao mutufe vuth beeizg soler mhe careon.y bIrtófesg the namentod woveg
# fat pos cose tham f he femeant ac tho card of the was holw comkfarter, and to ane to m
# the sisrt in puse the somkenát Sesez
# wapist Nome in bos go kather.
#
# The cofateefent Herraus bousd
# “e has sat show basoonde gas hey leelíelró Ator the dourme of Cecl thergs, autytogs, Fsathersud Nast
# “Noins the Mlencidd wisto the
# purted
# wer.z, she phound. and burathod bseme, wifteoned nel
# now daing his rare aid geom
#
# The doure pottle weoe pounded and tontónss “utent her ons they
# ttenp fhifpejecarclratef loakketitsads andatter he thruschses comy.”” ther the endace the caokigly
# And ans
# liin hime,” cNesine aus stel? orif seitcsoa.d tepe bell rak the antereon alm
# “ Berl
# the bepbowl “pomekCs,
# nockóu, nyre hretide
# in thefd”onc “Inale mhotoc,’ and boinges’. that hat dasssthe ferging, goy thr
# meefebe cangthef ro
# Gesherule wis
# the Boul, be ceing to Beml bne comesinge and
# toun apdsedd. ball...
# “etíevfeddfhsy Seche, ance
# drybF Anonens,.
#
# Ghau. nad a huat her ceen, buoith..
# vpinge A calint the boukanidtenid aytiresing ray d?epd. dourd outh. “ithorse sorws seeing date the?ch miciou
# dhane saso. idd
#
# Iruke, dirmfit! and lfos and so tas, tuWlitEm Khe wocmee the kuttt onky as the raisd to B ap flarerss Hith
# a’dun hus ref tat pardee ly thaclemstchteou in
# a hossencatesí of the,
# the ontecy hir kou in
# asd co
# tamle cod wéor pee mout wier
# dis! alcint of mlrtawd haviss.
#
# cáatser his litelel far alme anderd””
# And seaklass, abp in. gyowthad Weteltezacoon the ptavp owe bont the cheen fóit isr thel,. acin, attt, thece.vttr Bhe it afrursmin hith
# wikssiegen, atte mury.. he ceyee temdxd.y Xringid feimh andoy be
# selpyelTyritg al seoe hoast, “úaod yat that it tithecaulit, an at weol waic. him antictafattars, with a peour!”
#
# S haiss of
# mame to packsting Pierle and dord the Roengens
#
# “Ti
# peee Dour it pheled
# foreont hit trit he tapl,”
# the laidn som
# bNettee,
# nal
# lefelá Bhe dle
# musv!”s.
#
# “Istebhidt caming
# bnoml! ablr Mende wte
# cupitan the
# as apfyeruste! theagmd “y himp’k wacháal’ crer that thes.es but roullorsebf’Cw
#
# The to eleich Poin wedgeof the
# peeldnion mtinan.
#
# “Waths The dol.e catcrodeng lein merimeol, bur the ixesed lut at attiss Arousing
# furani itso, fithon the peing
#
# “Hameon,
# de. gont wtenetsec has abmud5y Ovthiteth.
# Toind
# selap:sseth of res masáerc Bilh letas onmods mrichtu,d htafe ard
# efk, alloysG
# Aórcón, I weraig her nate btimeo, dhd
# at ondtovl, andyr satvone seithe dad
# rassesfen ThamNs head Fen evumle. Torúsops, but hat deetsher? Poir he dist thet of the dusizatce rutwlot, bury Nhe pacleeon atoupr tow, aoteran and sesvingtu?d Poutse Pteml
#
# “Ayd
# byeytsol wuthad and seml, ande fy mest eee! he same Wo, tonsenke Fralid surcow e co moml Thoth tar,an Pnitke seid that e
# me the pemtiid
#
# “rA mtom son mes, Eulnelnydss Al
# she tris the par thot the
# Naltón, yas, Iry muit on the premer hel daids se cakluck
# thin cafpin
# tui, tho foud nos dich sotytibitte and wheatly
# pomking bastavitl “l Suckoor the sudtsyye te gased pre
# w aló we fomecsey Xingerl tizrecind tefkege thaceiched of maice un has mor, pet oupF tafe of a koleter, wexl mume hekint arsusm armligsonm Atow bousing,”. “ed, fanded Suithem
#
# Iralid
# “ut cans, Tome and Rount alm meat it lau Se, fott the porwed one heat of agllés pek ttery and nom gan wheak Ieíe byar, sow as.
# thes odian the foretessecattringer Sith a mut nith paution bieer. winrer Peiddne. ind Ilas the need don the wascetsey to glepEon, wadd altseape
# moin, ir sataitali trefe wangitt meeed
#
# “O her meed and,
# fuind has atlaseok sImoin kunteety Anterdl shemP” Intreecapebmsating foomicenf mIoned somping banceriseliths I bicean und
# en,
# a ded.
# Yeor oukt the dusrroy thes
#
# OWelev? ceeml, the Marsicrtcis- the sou drean’.
# Inale lading with at the vlerdend Hha aseye at the grele sous the pastee and íe wat see euse atintele, liefring geene, had e deidgubestyy them
# fringl Rir she burisgs Teeltionid deid
# the Eeinte tes kurithay mr
# nimnzet as th ap it wis. ap Dr Not axkry
# “oud.
# belmee ri? angiesstok cate in ontice yeinge and lome of mitht andockOutud ailr aul toat dhe fatu pontód and aningeplun;! byetherss suming on has nouling
# whe deml of Sreefestl Masad tithorid frac he lous, afy vritfui. srocokar muchtads Baie dhicl the potáer krotkeatke an a dne
# wad the rorets phe geit heoity it warter no-e, bus the tame of the Euaryinge Pith the gesonc. “reasingity warpeclontemalon—enc’owdsun. Lhalk Ba mmousiccef rob
# In at fadn an Poury Sont oneminyd
#
# TSicuthing dempethie in
# tho crou him myyrnísits? ard woutgy “ots interacse pikenta citteelsond Pumer, and comeane in a rurping? qepose of the dastis sas the
# guittly Bed pydevfaben af
# a andinted seitch of his parfeinge and, an omuot it his gront ber “e Bhe disgtovusóek, and the seinge, and to saiged, naid the bife had tote thes eemht eu. an chot to the cobegantaw, and disgressó, rrit of geingan of she cometht op glet wien chatkl To-m.,
# The show her thaig tatisinc to
# meoune, wir nore somean eou et a funcól thamighs to her pomelen, Ytitt the rut out rrecethad afpene Trok herh the apoud
# nat moronts, dousce in the surtt weadon.s. fokr wupen
#
# dLerered he hid dud nem,
#
# “cesali” tlinew a hadl of the ceickou her Noule ro hat lroir, pein fie deenod
# “eptrmop’eontkamá
# chemfnaobsu’d bS
# Vabmy—glvad Tot RIlowe innad the ingy al she e waw that were hed clsone that that onilpis
# ptietlyy it, a fainen’, that peeghva, himry, br the Littlrrerg Gastew of the mlpateed, bale bur sori—itios Ollnothes
# ( the lusun. bant her datsording in the “uchóa, enmer, timithteoth he arded Men cearríenteme!
# brichs to the damesing tiek
# Sy pen fur Nolour keapououn it paus heud bringe. Dit larp. All gotpittun humthe pedtilew foudd. betá thet tho neadleng nhetchol e, the folele wunistott he thef
# dedlowid
# dta ploaghey
# an them; lutetef, vaky be to the pou keek. Out erdw:eimw beidysebeten mroingese Eou woy it otind nrime andarsed tadr, fe.ing thought fy
# the proml; or a
# inince A
# ptok orain, hit slaring
# ul ghoned lv,
# pemali. ly cadtids- poitl
# “nimes fhet Sor Goun, an the rowe that meis Keetss qit fouass. and it ander of oun inftel.” burt,” andes. that cort wou renel.
# buelrv, wotionter.. Pis phe yri ardasid lut and to car
# puscuby iateol
# ar a yather, borreen.toclhyres “uthousing wieetid
# I aite und fertawd wem
# nin nat lyoná, fut netimeon andneousy Mellsh a hean possardas, twono,dedn..
# pale nos,esits Hlincesy and
# yravetife Iuvele letht pemeont..
# “Ids..
# und
# of the caintsesy.
# to tep navl hur
# “Ir them’y
# Yaschess fnom coCdit.
# of oucy the
# gact a pher waing him do! the Vofdek!””.” and tuvl ghe ous fakitov
#
#  Chnseref Boiich
# “her,
# ane teatsran’ fO gulings Psade, and a tule,
#
# “T that he oosryy
# rash thes caich, sis
# foisad bni
# an otame?”
#
#  Pel ofou ly the coule apoo had asterktomeingy, Nhat ollul,
#
# “ong ysantes, atotteoundé. the ghe
# offlatitt dus’tov,dfs weidy Bidk that the ririghod ext bulv oferuud. yneld”mph,
# toose buesr. Anf winges!ain bor hoa ceing wit asathen. fithiol,
# “Nrace bumen fell that tousy ipuleon, sho koud ir thatt ofp the srougans besk omcrónser’! and huis ufasonyl. “nincessotien Nhe boidsenl, sot retter “ifl
#
# “Natc Baw; and pezin.?
# Boment he seas fond the sounkl, of,” che brilkett hom,”n
# and envy inachsapw afd sutiou millrkoksSant wis hear,
#
# “ heat shouthl,
# Proolk alenow than he hovine that eorom me mnethenss. Aedame in the lar evesnisgs bo vechialn in them toin on axn, ind yomenont and al logy “ole ind thefpd
# capexran the pther souchtan baru autr soD! anethingen witges to and mihgert speerard,
# Fesan lile of Khe coráun, Mritce,” Mrootht he caud to selitns Ral oy ratticed wyle! them Nise neresabe srrn wid atte daster and theys yesing Boumoun..” “emes, the peoits celelene ocourun’ Nhe cyalrhed pAvpeaten. rheth” he he.
# toiss youcht pAresucin she
# otove canion wotser
# timfre Diezror, woined be a keesyd fethkrizthe sidtt afd sulogthed
# frittle;s hem teibe, bet arleticfr she tow’ers, and an that, my
# alpt how wave and bain hat bot tuith as Womamd “at ros ap. Nooks, thet A heav
# rwe
# fout. ho feins setsou ond btileortawd “fit’erbou cotiov then Isl Selk thrar coníit hir his poumy ard she cellint armosint. Traod
# thatuze riear!
# “unt thet they bTluz wut ceaidg “er baling rit arleretety
#  “Nacpos to poces aurunitin fuve a muekynvpapileontem dOo herd whe it the
# domre
# fefe.
# “e (adt thos hotáed gaicen.
# vurtras, nougp Thin Hesning,
# “Alle. “t Ip beylvpying”” him
# nedd
# and por she ceek. of the foulaw’esl! cas, shrsent it tous hielld in
# mirdaw and targerfau. Dah iittant. crémend Hid nisghor beul, yerd of to the fefssatedy
# afl
# e cheanef
#
# “
# fe Vsun paal Petarf,”
#
# Simirte and pou cefv
# mWote. eed
# gte Mpteolrey her bousou yemitte as a cot iit hat sonin. a wit pinemulileon polerele, and he alsucelarinmd guin he had Nele wawdsy bart tompecló. the dommibeores! cuo! fvour! his cpok,” bIr dres the comrod the “urinels himus?
# “Thit?,
#
# u aukletion he opfenss mrice bele mich Ci”cctoge ins a pryr? Dtuige. “esíine then fat’en.
# deinen. assun shouting tussowken In we. tonend the ol Pis, avtircan abeny
# weagd
# Pitiseon tultkat it a lorf, said munt ixntousd
# far werein” end he deer fielr, mulett Casl. af
# tompew pomesh and naml ar tomeshin. diltling, buicenatg ha hed at oul e pel. yes.ared he per, gutyltant al heath mortly
# “Yopeingt wut ro dit poopen;r
# a mam mtout the amenyn woilts
# the
# sele
# purcessing
# dar feening thenlsefd
# “y tomlodhensens
# onder, thith he atonions the itteancy
# cein te klarls,s thope wus otheult? Ain dier feaghe fopceen
# secledt mimarh filuzs,
#
#  hut pE ofe. he rain Dosr. “ather, ingepeod theis, ind yididt.. Tloidd
# nad, thei” touling,”
# nast the poste and weerud the lrhe Aracet. cowrs dest toemungk. at, seht thasces to arod paling
#
# A
# o to yol aflou he andthes ghe—alsed the pren tre ark his deen
# ttat u ther Sepo yetyags of hectl?
# Ves tont ofkne maslyr. she *lpyrs hame hot and ugresrepung
# we
# bupwr bur creifhss anderece nem
# nurt che poop onk
#  Gou ry che daveing horgóon, builnt, wollshed bumser Iutclv
# mutyed Ger to the ally alingen
# Bite wefcode coo’,
#
# “Whatsidge, hem andinst Ales
# shot che
# witcerfthourd an thatte, heard hear hang of luryou atdy oginef’s.an the dau out to andurvk tow the eupitidss Miforey lrdecy,
# a feingeouly, that, and semoith Prr
# ofl that daeper him tot Batuse. thet,” as his casout—b the femont hear, ard the soomen. and bot of that theeb
# abayf, and cadm thetchencs in Mou eoe
#     Whe offetht
#  The gtoatid an wuy,
# meirtt afeo hem port of bicher, hellitedes, and laighs kol the allyme wesceingéu Por ghatin, his
# ...
# Nel noun ‘utht on isvitt cavlese, puithed. “rome had fieths, an mólu, Ptat wethee, than hef lyiled Pouny yhape tullynoukh wwdith atdoy jasá
#
# “dvtas!ou hed cioutloi’ my koun, Ilin oufand
# “uhting he rarsars
#
# It hethe.
# lecaciths “wethed bungercyrkyd sighteo.
# mee to wer Oee dasr of
# thes the qoutk,
# “usitire nad bor. anderst.y” tutherh sapome, and brili’.
# and Rasit yed. a had beetertem
# itt suigted ande
# wat taa alfly Bome wodsle and Sart the Eautt and yetiontid aldon’iolebe
# cther they Altubat nel.tswkant atsers,
# he atkicon burcke cut nomded lplelurdádm., Hege themingly
# Ftece bugpning ofsesenitt uvneorisg to cian he sinfeing In his mellaw mehtered conkas, Wuly ll
# ceht heepe sottein hime a pe the domisadl af ity tos souser him shell, itith om the withat Sotte Slorenn
# uhp.se,” the loskes Htro lottop gas
# bonti waw rowd
# lIr purkited rering
# at astimmnibls
# Ppawce whourl, tale in the co
# con naloloin er
# muritt ind Ninnsunts outter, coder that that tuerestl.
# and topá
# yrav, asd, andtits the couwn dhe yourun Kame ontickr the
# metter, foritu,” Gaursed Hi féo an a bitata porúpe’’ wart intec.atkly pot Nimpeousgant this hat beitse ofere mout the dagictovimir to Psou heelandeon at loce of the
# but mutter,
# AMrilend cat mout hom
# ande than mne,
#
# “Nalds wath somnaes and of the. thear!. “ither,” hem muitg
#  Alo rot aticoru epoun it fisioue intse! quts manc Isitge And wieseled and msowge cememdengs! Hh
# weed fomeoth. nawding and tonnecphont the mate tee gaing oue a un thes sos wish af! ard ponty) bv to poNtan dout fouk the sut mitt mrom,”g, Tracproy’, “ut doleou mow karú yeonted síIl Ivth
# the segleyd
# ind than
# avk arsyr Nilotcëparion, themphad he the guald the bpont
# bAáemopi woslots andortan’ingen the Erefing rain yee gheninibun che thit onciceud ly Hidrebe;tas, andaringes’ep!”
# wh
# frreoncard lund onterchtin
#
#  Helsing thek
# atee,
# itemyn the pomes it avly to the bark ceouth ag
# a ham
# mos that che tartww. Nole. webeltue (ouldsomi”
# witsing she
# roteeyt, of Beting
#
# A her fough,
# reetses.
#
# “Thyig—edcly gow
# po
# fean an and lase hat on to teed firtirputcsIy
# that shes weer
# wér! anyy af, our roved enumr—reres Keipr of anged the
# fecany. wusnze wow droolk ful ner vas she alfesting reat hamp,, and ther his moa in fuit?;s.. himt for gutúe unteceoted aly
# whance (astob af Xist unnthen, haddar wiveinge brentats of deckegichings his head Ruity he dibese”
# VWome,
#
# ut the seid otiot.
# qot ther om the ronr wrile chisk—erd
# bLe hale bet, pome, (opnoy weiting and coind lor shethed they Pmriliti’g andy wookd auther,, atdt ur
# cefer at hes
# comy co that of mejhan him geatted hot faele. the onmr.., Axard, Buce mling cingeis! The mideny shise Mor apk u dalattly,” Hid waid nossew prouche. ridfedl Trercerhe hon creyttesr bart.e wed andy, in bóol Dith the tule rort of them
# had.”
#
# “Ilecht the onmowimkedce,” “uned ‘ut, hem no nis fufebakeole chicpinye, bpowe nas thop ind and the frente fhon fiesriss Se erakonud whatt rumope kramely
# cyil?”
# Bad cwowe pernelarticatililu! “oich qye louk, ensirston, and theiged, wurlsplalle
# und de’o o nuasey hed dtomping the Codttevy Woste one theme, sounied wift namd
# that the mortórsitt and toopf miether ftousd faltresaoke,
#
# “Náuwd SHá:eílMó helsedlebeconme “ene nur obes one olde
# the chod hus, has
# bute
# acd Hantlm alcanctions, ho wow and muindt an itter byel.
# nime! peomn. asl lur’ens coingsin) Nerthid Sat boeprt the liles asdached in the arrits that he sar
# noun Salont to jou wast in theus of a euttl
# Pm., that the susszoudde
# relthering,
#
# Dithenssy
#
# aclsatilpe lantey, sod
# vedet whom blel. The parne to pacn what rhee,”
#
# “uc coutdess ank nad. a role pucl attorent han avtyingioty onde octaolr touring Setepe ar bastlrye, ghe nes bathár pilingaging thoumeen,
# “lhesing alpsin! and and muth to the cloutht to sey opou he sontince onde belouned
# cot oyeont
# Aeooned,
# itse her hat herusule yout thesk mugt Posant mas salent yem? pelel:etiter i
# faid tole resned,” the berneveeke teith”
# Wand tippett,
# “Watortem
# uad bun the sruntenitt rerar, him lord povkenion Diergsitgan beakonv, bTó ax ity
#
# cherevpattings tov gent yeitl, butá. rad jar guyechtuti” an,
# komenop his Nomle
# andsy Tousd houd thentease!
#
# “Nhe somang
# seatibe inel;
#
# “Yathn lo,dy end loiny
# ook, a peat of thep and pere to beat heg,
# hte,
# and klo novf
# nuksow, wishs the
# etousd mou wivirses ofdy anky ar the the on? nus figts ag thetls
# Axutser
# htin eyeoidd,
# apdral
# it the alkiosed the mthat thepeoskid rotertear (; Oeo to
# nembe And.aw. the cenetiol
# Nith theasing wom, aoe. the bosen turís
# in Itsar he Rulphe latíy ifjran his ar hat koitt Ar bon, begtels Pas rhem yar the frilpingedss paing,,
#
#   Yee aseomde she Axfitims of
# “ MeleTB that Medr bithour the prielel,” he itsisw.tr,
# “No meoloked
# Jelh! wr,er oeth sly wat ferkyrirssye, Thin
# undesly Nhes the durerhey
#
# “feshs feidrly Ar the mos—y, pur the possretyisce
# Aotidabi, teo
# pontt. Anink, wame naml ofe,
# and mieled”
# Aleoissy
# Al.atwe, Meos natkeofe!
# aut aw the wome und lo’ male! bussang
# dihg dovmow, Nhenching! I’ateon puoars en tusu?d
# the catseruited
# rit him btherume
# ar ficl Rymun ut Sijttain cery Pud tome gíeal”
# nith him todt that his his fontóelsateon in hed. hey mouryoy wigh he thot her lettta, hte muyruy mpomphoas yrop of ance bets al that hiid. frartevfumestechebpe, apont courhers, hed lhe himitetitg ut Aluthuy thenk, vuspersale deesed
# wad aby tomnsing the mrood, lalp. pthee, and shol he hulded erince Andrce Bo m ner nin., at ciseler and ghat dhottli pudotad in reirles, waiter tupe satsay both sopise. woiteone tostse
# Wucist Mmriched couny
# nat pows drine weat No hanten kre”
# Oete beni Ne’,
# Pise
# al brod ous goll teme becuidnt her the
# pllangpallebsl! Bhe sale outh so navd and nole
# Gtem,”
#
# “Ilun his to kurenc. Amar they Rfere’ing
# tas no b ofe
# “ao not Sle. toukd lousy nem goughing at it to mlaoe of lImsthes onde, the fase the hudped they clatome werare
# way ho
# peree eltelnangs wer tabioun kymxyfegeon’ar apl no sokéuse’ien, and dDet borghen ane ponss an her
# savett roar?d Bas lou wrase gee in the lut the gout tomk.,
# westair flr the caprlmy the dilpes take Moee I that figlatt timk Thitolee ne ceoky shoth se thist the (um,”
# “atgev
#
# The SrertirvvfrVersher the
# mnok shepe wmisttyr., Pacle, votte ar, Ios the eljpatenent reat ai weau,
# ut fue anntardon,” head tith
# semalsed rare hag sedlh and faant and oemete andred? inters aleirent his
# mIaren, bullited the “rou trry Mvurel, An that lteyly were, mefl. and the cagkearkene?.
# chit pyepenmr, in a che blore acone fust a sousleds
# lyesing is Wudelablteni!
# in fussidd to me buit, of bv amst the seighode fuymâhen
# bontabetince dhilme Bhat in aised end
# as the rookîon and norree.. Heer he htaoidd, wlingt Rar,
# Cese to Das, romnoul.! Bundsirg exvosicious!’ the yordeh’.. “insson
# her all topeevez Aba,g heyt the hep mechory
#
# “Apine—ud. Pe tude in se)fsmR “WIVosl Roing ut
# mookeide luu no bouk the gorlin dicht hei” heid no he arfynoutht Hrauth.. so hir pore fir, sur faxant austife, pusíshins
#
# “Aká teid
# ar a fean and tontersed andouphev,
# an his Cean dhein heare
# nas it the setss the gureturs
# ap thess onith rhe sau,
# it mravid,” Suncarpent the doul yere
# a lnichees feefrutely mun.sile an ther healenad putyht her atou him dother to and wigery,”
# nadtou Veer v
# Ofe,
# dhing ho toincisenm.
# Bot filing el atsarded Jtin htemk. Onince comdód ebpidf dat hat dompy ap unceenstl?
# armeRráto Ias of the ract her, Pvontey bartls muud inith there her.z
#
# Dis facatt thom pale oud! andner
#
# nHan me cro posd hamh bull wopledtat’ buid he have i
# of a und voin inithearing
#
# Wicl nous then, of thouge,
# the bou lutiding
# “ele. arce canittotsed Al wes
# guresol mrdóp
# faid. and the Dour as ror mucle?; at ap.nid,
# pedting har have of the dirlsy pakpitin
#
# pVew,”” here caedt,”s. Axsther Yrem.
# Nhe.! than had” Anda an the
# ardele,” rran. woumd ale bunc sree ar oucw the ftouy nar myeng to the natkers “ain himeseon? bomit rutsee, womct hithen wad vut’oned takks and mrink.
# A merú Thouts
# mex’ courtton Bwas, to the cookd Ilince
# “eter mos to Peer the fith in had
# peaser Hporere., pacher
# fattee mouchte rawdy” Pit hu andod that isonh
#
# fhe wtele eef noty af dish ims.eitermluming etoy, In miifenc
#  “Iothed
#
# the pomtód he Nalt noucont feitted itht,”s
#
# “efle! “echityeyeitesd. (hitele. Varch so the dmats tur kor doule lone the onte
# thesk ar P themelpelf- co ane of aus. to thait hat lwemilá pudcoyingeonidged beich. cringed acoun towíor bad om
#  Cqen mranchis hot abfmyends cook agdes hat lramant in the pouving metrind how i pola fan bicht he lheved
#
#
#    CHAPTEv Owe cour A lening that temorek”
# “O Dit ml hrechad anded tevpa! ho din rpreavns himl labk the clolpen mal asd of e te taidd” in f
# rairh broteon.
# Len.ef
#
# The dole theure
# and.sadd. ter, hus sollad vuky bratt that isrefpyv
# Wodnía aite in thed
# a pe tudd the yVar qvme arl then huad pteme iskey wasinc father; phe brow axme head as,” wlevings “ere it the gouky rot lreantlouds heud loid of the pascer gon theifant tos ghe crun, dratked wetheale soudsent ous hise a warged netoithtalt ror culetth ’eflefp Fad hor ctane, hime “lum
# fhetkse.. and to idfatst ondirtt he pee pefü?”
# Nhe baslling the cou lon, apm mexl. “eth arsaring hil shesud et micpesind. asd Nuule theth? fontee
# rud andar thin sartontatiny tount he
# purem
# Ptemted “uichtour of dor, and numpeng,
# “aith osle witteois Nhe atsemrttye gyur
# ghe lNoop bog cplGs?ciling Heceses?
# winges,”” of the
# worsort checel.,
# and
# nousangy Amfougy then it the dogter oflancyou hidse, to shin, crol Drging. and acl
# che pTotow6
# wal, Int, tro ceifmas’erud “utáead cet dale teigudne lou dabe andchrseoide of it minges And atsol.., the coris that etouthed to dan thi lorerds, Bhat had folkevnich ytoml. bew nith in had af that in the fese avpestatcie,”
# niht on war itutising his, the har herreng at the wastse Aith feat,e win
# peth dur the Fam had ob has dele intice tamnont hotíetint the noug eikt the luncengl Iétow time mowud of,m vlent hes Pniish, ondeont tuml of that che porlsomesh”” ‘myid bort the wamplu baie as the lexptiour fit Inu. of cert Noumnon and in thatheaby suym, Yut’erel
# Pisele, Neec at rou lpence Nomíel,
# and Morteyging “elfetuks and
# other and srise thaxpsos’ lGeon Oen
# so the chaten he pisfercetittont nom,dars she prince Antr, bebuite sam ónlmsing. Apr6elr. Hxenelfs.k, Sontume seme.b
# sot mieupis him weruthey. Meer Coll
#
# The bitser?, tuol-y atder Wame of the auid
# salpee ptit pule it that leestolud pteith he geveryy muttóote ner btomis
# In leen tudtesceynedt of wearde ly Arhanmy, wole onear it witturan he huw ef the Phow hotá the rouldn, and.e
# sowdseatis mou maru. Nuclits to tot the Cering the out the ag)á
# fel’etls, Pe pus,””
#
# “erth sobj the of exk the fome, avuve etitealroy and
# en thetev
#
# of the suid me
# nersiseli” sether
# he
# srratcont ind arm wow lsloakc, fongs peinid ham
# i tule wacle—o drercesr
# Ryr’ur ther his lomernotsent or kheml
# ig
# Coráing blint, wai” aus If byg.the now ghes the reml yLty
# ouke hesthem. a unze,” lobeave fuirteg crombedtecant SX atomy pupks;nsit’. Ane seime her vynererisc, and anfids, and yuptoun
# the cale bou to Loun the ppillidestsingl, and douchen, of
# she crad alnige of sist “oreepAxpt has pet his somv at Cee” It. Fesh and vypartlitcye
# A Inather,
# “
# vatt Kratcinn
# deidse
# beigints Che
# wilp., ande, he hor
# rrowe., 1ne tealed
# “CveThid Mowigbleá fustur The hemm
#
# “Tow aldelssing hot pevingey, and the pamkrt Rolanes butithed. and pTre tamlabrtang a ceecein. rar
# dursevfe sasd me
# matt the pertricthes wilh.s. “ues dout theerh is comlyf.!
# u lou nors,
# “un ins
# latt, anole mupt!
# bVoná
#
# lTapiened Nedsible to pake with hem Eary her gre sond Ol theid theint lehdssed. that indwe plegtssn
# Xours. roir she pooge in arit sasish she
# gemrt weevk nampestallasinglypsing the purfef
# so. wrebkThimis.
#
# “
#
# “ the bamed
#
# MYe cyenep “Titts widreont a fus of desule temering
# at dow’herucin suthed and in anem, liting yIlt the
# pant frevich. wyi” he
# efmitu, atms ard asmy the jtusp Awda, dat befped, sule
# ond bnichers an sart faucente Vefing the malifhs. with?r the pemoith and ald Fotting mory Ilerher inatted lentovney end phavd.s, Eekeid it dorditg, befeds leilon
# “lou nor
# an
# yut por,in. Ecuthed ander, ther, the bedeseon e—chat he sith.. ltoo ero nuvsectmy Hoy yhe comeon to
# mengebugilfe8itione. as buks, sot, of esttersert flean
# bpeov’ing an hissed tustated” crom
# it tointlou futt u wednalid Seetir,
# Artevicinces. woece tan bemt fwincint ancysith
# ut ofm u doun wetteedd”, po?irhon
# Atesined 0eb
#   OAee the, rhe yowrin, ond it her casvincetk
#  “nether.
# fan a lushon rale hevne hat han eleithow daid ney Cat serper
# beet wor lornefed Inis alpig ficeadsssary Iti”eng fithons of,eled tad Secsey foop the bors,”” stut he. bett the por wo yaun of vekring elit the crithtey Theu moung Oucy vone met nat hon ketisvencer!
# Suse the sron, ardw, ttin Silphs pumäin hath se fepurhan at onnt. Nure of the crewed
# writt Neas “ony, and at
# meceotem lipiol te fukardon in evsugiont and Nath rrit hondetert the Sookd. ta reee, ate aefr ghat whew, Muted, ho deang them neonts dout he theegs en
# and ruide and he gearsid
# sovelsonit he cartir leathe he poids breml!en. aklo.sed a peko cetur Yuther
# Sithon dom
# navemant thepleml “ettor’ and helint lungans?
# ned cre
# ltokins’yl
#
# “lo Cou gonoun bit lam, a lat gererobery
# and leltad. the satiousy at’een. heth
# “Aerles! “yruchad bm ploothens nimsensun cufenad she sadd unefuts and ancett mphte to and this buftee it drow the Emet mon to
# tóa realon, rer and to pl dapali”el,
# mou, he puit hese
# wy Ixic Peel the popour and to sem?” dwetred Mosém fept of mefingerssú”
# fichem tougsith muin mwre ben
# her tade the perlbmh’
# and hot the
# wecupe my and ritht bNhan
# enolen, in nere betoussóde. bare he an, befarant biantedn. andol- the sourd no e to solcebanins it ouls pufeone in” somor’e, ppavketceband of the murter, crin artebfed
# notve vikl to gou kront mas hads vDbalint ard to dou po coun hud iwetent dist te Aier of alk Montep
# in whitghim. him mlur onu hed ertulsidretads thetsestangoutestan, and faid nus e bne! trat alarits ar theid, be to the doitenll. Eun, aott aeth and
# so keince2
# then Suid,
#
# “
#
# R tout Pis so ofd telphens it the mll
# “Hne Taat f’itcloVkerkP A copfe wot onata ofdu Mokw Nuichtes! Isdt the unkalirtse’s pegr? ouketot bee ine to the Cuull and to
# “nAseours
# neca,” ber so derening at opf vunion by Pniflen wrextarisgl ur theis. evat lovk,
# nmod heagh bel thet voringer. bSecretkm?, nad, Ruplon.
# mlesóding, heale
# “
#
# Pmpe puchtev
# ‘vh.i, atsunned shoumyng neid the sukeicgoy douk?ontan and fusgenmeng Mint the watsarcorays
# Fet pee, the pume tey wurt onmth hud cure yownér
# desn.e
# dede the dmjathen wor am,”.
#
# Achers e po
# moryabe’—lemiteb “epsinge lrenchen. busvend
# was thmin sere undire youettot P Nou, ixl
# the luck’owe and to theafdd. him ned lonslrs? Hurtedy nad mteatent mar abmathen’y and wor the blrufovirs? and han?su mfening. “To os qsithen.k
# end mobes, ovby.in thetsed ttis andyranesis by
# ther
# kas kould bue nas onche kirrsin
# bocusal a kat be the vpne afleeledg lunt,
# and he iityl,. meid poue inser
# that Riet webslat.
# thefelesy.
# “Yezezevy An takpre asdaseynsying fhicet ot urincyou her boalr A lain an, dot har she
# comfy ous Ilerun.ent Surá a simn the
# armos,ad timsuy. then they Xtune hid datásith a soyd and co hif ovefed anmthant the har duther.er shetu bope
# befmksedgts At mevy yloaling
# Mlazshoun his hon
# acthants Yovntesuk
#
# “O Pes nhe shince, hef
# awdancof’aced
# Pero ner
# arled and ousid, lee, beoingelsilpe, lrule hat srenged Ptiwad
# to he sain pot sempWres mvmhun lorine yourdóy at,ols Yuttór.xunt her sthe
# antecas, nu’idg to Aicher tilurded ardonings wivesid Sy agathing ttatteriztl OMf
# basy peo kv the war—e omle.tter lintleg,
# ardursy “urtedge than the
# feia, of the pooid
# T
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 11
#       9 preds, loss = model.forward(x, y)
#      10 next_char = torch.multinomial(preds[0], 1)
# ---> 11 result = torch.cat([result, next_char])
#      12 print(decode(next_char) , end='')
#
# KeyboardInterrupt:

# %%
# Test the model

x, y = get_test_batch(32)
outputs, loss = model(x, y)
print(loss.item())
# Out:
# 2.2150869369506836

# %%
batch[0].shape
# Out:
# torch.Size([5, 3])
